# %%
import pandas as pd
import numpy as np
import os

# %%
# %run sqlite_execution.py
db_handler = Sqlite_Handler()
db_handler.get_amount_of_images()
# Out:
# []

# %%
# %run collector/collector.py
collect_data(db_handler, "https://freebitco.in/signup/?op=s")
# Out:
# Loaded Website
# Launched hCaptcha
# Switched to Captcha
# Scraped hCaptcha string: Please click each image containing a һeliсoрtеr
# ...
