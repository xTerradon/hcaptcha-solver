# %%
import pandas as pd
import numpy as np
import os

# %%
# %run sqlite_execution.py
db_handler = Sqlite_Handler()
db_handler.get_info()
# Out:
#              total  solved  unsolved
# bonsai tree    130     NaN       130
# helicopter     246    10.0       236

# %%
db_handler.get_solved_unsolved_for_captcha_string("helicopter")
# Out:
# unsolved    236
# solved       10
# Name: helicopter, dtype: int32

# %%
# %run manual_classifier/manual_classifier.py
mc = Manual_Classifier(db_handler)
# Out:
# Setting images for helicopter
# labeled helicopter/08-17-17-41-425058.png as False
# labeled helicopter/08-17-17-41-831797.png as False
# labeled helicopter/08-17-17-42-245808.png as False
# labeled helicopter/08-17-17-42-649677.png as False
# labeled helicopter/08-17-17-43-175019.png as True
# labeled helicopter/08-17-17-43-623547.png as False
# labeled helicopter/08-17-17-44-036563.png as True
# labeled helicopter/08-17-17-44-463918.png as False
# labeled helicopter/08-17-17-46-041639.png as False
# Setting images for helicopter
# labeled helicopter/08-17-17-46-479456.png as False
# labeled helicopter/08-17-17-46-892086.png as False
# labeled helicopter/08-17-17-47-293428.png as True
# labeled helicopter/08-17-17-47-762873.png as False
# labeled helicopter/08-17-17-48-208403.png as False
# labeled helicopter/08-17-17-48-616470.png as False
# labeled helicopter/08-17-17-49-039520.png as True
# labeled helicopter/08-17-17-49-458926.png as True
# labeled helicopter/08-17-26-14-997090.png as False
# Setting images for helicopter
# labeled helicopter/08-17-26-15-495660.png as True
# labeled helicopter/08-17-26-15-932410.png as True
# labeled helicopter/08-17-26-16-390493.png as False
# labeled helicopter/08-17-26-16-838034.png as False
# labeled helicopter/08-17-26-17-251463.png as False
# labeled helicopter/08-17-26-17-662425.png as False
# labeled helicopter/08-17-26-18-043585.png as False
# labeled helicopter/08-17-26-18-482078.png as False
# labeled helicopter/08-17-26-20-084667.png as True
# Setting images for helicopter
# labeled helicopter/08-17-26-20-558019.png as False
# labeled helicopter/08-17-26-20-983306.png as True
# labeled helicopter/08-17-26-21-444035.png as False
# labeled helicopter/08-17-26-21-862961.png as True
# labeled helicopter/08-17-26-22-287281.png as False
# labeled helicopter/08-17-26-22-702941.png as False
# labeled helicopter/08-17-26-23-118632.png as False
# labeled helicopter/08-17-26-48-133407.png as False
# labeled helicopter/08-17-26-48-564483.png as True
# Setting images for helicopter
# labeled helicopter/08-17-26-48-991347.png as False
# labeled helicopter/08-17-26-49-410757.png as False
# labeled helicopter/08-17-26-49-846021.png as False
# labeled helicopter/08-17-26-50-263930.png as False
# labeled helicopter/08-17-27-08-206053.png as False
# labeled helicopter/08-17-27-08-612746.png as False
# labeled helicopter/08-17-27-09-036116.png as False
# labeled helicopter/08-17-27-09-461719.png as False
# labeled helicopter/08-17-27-09-869680.png as True
# Setting images for helicopter
# labeled helicopter/08-17-27-10-287050.png as False
# labeled helicopter/08-17-27-10-712272.png as True
# labeled helicopter/08-17-27-13-040661.png as True
# labeled helicopter/08-17-27-13-466550.png as True
# labeled helicopter/08-17-27-13-899512.png as False
# labeled helicopter/08-17-27-14-348580.png as False
# labeled helicopter/08-17-27-14-749513.png as False
# labeled helicopter/08-17-27-15-168741.png as False
# labeled helicopter/08-17-27-15-636535.png as False
# Setting images for helicopter
# labeled helicopter/08-17-27-16-050337.png as True
# labeled helicopter/08-17-27-16-487945.png as False
# labeled helicopter/08-17-27-18-988710.png as False
# labeled helicopter/08-17-27-19-413883.png as False
# labeled helicopter/08-17-27-19-873506.png as False
# labeled helicopter/08-17-27-20-270744.png as True
# labeled helicopter/08-17-27-20-700136.png as True
# labeled helicopter/08-17-27-21-098728.png as False
# labeled helicopter/08-17-27-21-513398.png as False
# Setting images for helicopter
# labeled helicopter/08-17-27-24-077490.png as False
# labeled helicopter/08-17-27-24-488005.png as False
# labeled helicopter/08-17-27-24-904453.png as False
# labeled helicopter/08-17-27-25-323387.png as False
# labeled helicopter/08-17-27-25-767689.png as True
# labeled helicopter/08-17-27-26-183805.png as False
# labeled helicopter/08-17-27-26-613602.png as True
# labeled helicopter/08-17-27-27-024779.png as False
# labeled helicopter/08-17-27-27-455700.png as False
# Setting images for helicopter
# labeled helicopter/09-09-39-05-287132.png as False
# labeled helicopter/09-09-39-05-689383.png as True
# labeled helicopter/09-09-39-06-086861.png as False
# labeled helicopter/09-09-39-06-482314.png as True
# labeled helicopter/09-09-39-06-890568.png as False
# labeled helicopter/09-09-39-07-296090.png as False
# labeled helicopter/09-09-39-08-990755.png as False
# labeled helicopter/09-09-39-09-381204.png as False
# labeled helicopter/09-09-39-09-787084.png as False
# Setting images for helicopter
# labeled helicopter/09-09-39-10-209752.png as True
# labeled helicopter/09-09-39-10-593929.png as False
# labeled helicopter/09-09-39-11-001325.png as False
# labeled helicopter/09-09-39-11-400937.png as True
# labeled helicopter/09-09-39-11-798215.png as False
# labeled helicopter/09-09-48-23-776471.png as False
# labeled helicopter/09-09-48-24-184979.png as False
# labeled helicopter/09-09-48-24-595904.png as True
# labeled helicopter/09-09-48-25-020830.png as False
# Setting images for helicopter
# labeled helicopter/09-09-48-25-439821.png as False
# labeled helicopter/09-09-48-25-882444.png as False
# labeled helicopter/09-09-48-26-295827.png as True
# labeled helicopter/09-09-48-26-715153.png as False
# labeled helicopter/09-09-48-27-123024.png as False
# labeled helicopter/09-09-48-46-207746.png as False
# labeled helicopter/09-09-48-46-643880.png as False
# labeled helicopter/09-09-48-47-067979.png as True
# labeled helicopter/09-09-48-47-481211.png as False
# Setting images for helicopter
# labeled helicopter/09-09-48-47-902711.png as True
# labeled helicopter/09-09-48-48-309025.png as False
# labeled helicopter/09-09-48-48-719616.png as False
# labeled helicopter/09-09-48-49-140880.png as False
# labeled helicopter/09-09-48-49-556406.png as True
# labeled helicopter/09-09-48-50-195603.png as False
# labeled helicopter/09-09-48-50-592271.png as False
# labeled helicopter/09-09-48-51-004173.png as True
# labeled helicopter/09-09-48-51-406308.png as False
# Setting images for helicopter
# labeled helicopter/09-09-48-51-798282.png as False
# labeled helicopter/09-09-48-52-204963.png as True
# labeled helicopter/09-09-48-52-602002.png as False
# labeled helicopter/09-09-48-53-010520.png as False
# labeled helicopter/09-09-48-53-417162.png as False
# labeled helicopter/09-09-53-48-154342.png as False
# labeled helicopter/09-09-53-48-567835.png as False
# labeled helicopter/09-09-53-48-996029.png as False
# labeled helicopter/09-09-53-49-413050.png as False
# Setting images for helicopter
# labeled helicopter/09-09-53-49-856952.png as False
# labeled helicopter/09-09-53-50-281104.png as True
# labeled helicopter/09-09-53-55-489029.png as False
# labeled helicopter/09-09-53-55-913799.png as False
# labeled helicopter/09-09-53-56-326180.png as False
# labeled helicopter/09-09-53-56-731619.png as False
# labeled helicopter/09-09-53-57-155787.png as True
# labeled helicopter/09-09-53-57-606400.png as False
# labeled helicopter/09-09-53-58-038565.png as False
# Setting images for helicopter
# labeled helicopter/09-09-53-58-455106.png as False
# labeled helicopter/09-09-53-58-884594.png as True
# labeled helicopter/09-10-01-09-065264.png as False
# labeled helicopter/09-10-01-09-475459.png as True
# labeled helicopter/09-10-01-09-876465.png as False
# labeled helicopter/09-10-01-10-283767.png as False
# labeled helicopter/09-10-01-10-695222.png as False
# labeled helicopter/09-10-01-11-122282.png as False
# labeled helicopter/09-10-01-11-542314.png as True
# Setting images for helicopter
# labeled helicopter/09-10-01-12-011701.png as False
# labeled helicopter/09-10-01-12-440697.png as False
# labeled helicopter/09-10-01-13-023283.png as False
# labeled helicopter/09-10-01-13-508954.png as True
# labeled helicopter/09-10-01-13-971007.png as False
# labeled helicopter/09-10-01-14-389367.png as False
# labeled helicopter/09-10-01-14-854225.png as False
# labeled helicopter/09-10-01-15-339513.png as True
# labeled helicopter/09-10-01-15-740350.png as False
# Setting images for helicopter
# labeled helicopter/09-10-01-16-146060.png as False
# labeled helicopter/09-10-01-16-573300.png as True
# labeled helicopter/09-10-01-25-427882.png as True
# labeled helicopter/09-10-01-25-848339.png as False
# labeled helicopter/09-10-01-26-263857.png as True
# labeled helicopter/09-10-01-26-673041.png as False
# labeled helicopter/09-10-01-27-097065.png as False
# labeled helicopter/09-10-01-27-508612.png as False
# labeled helicopter/09-10-01-27-926404.png as False
# Setting images for helicopter
# labeled helicopter/09-10-01-28-320090.png as False
# labeled helicopter/09-10-01-28-720096.png as True
# labeled helicopter/09-10-01-29-265438.png as True
# labeled helicopter/09-10-01-29-683040.png as False
# labeled helicopter/09-10-01-30-098833.png as True
# labeled helicopter/09-10-01-30-494741.png as False
# labeled helicopter/09-10-01-30-914468.png as True
# labeled helicopter/09-10-01-31-316535.png as False
# labeled helicopter/09-10-01-31-730536.png as False
# Setting images for helicopter

# %%
if False:
    # %run collector/collector.py
    collect_data(db_handler)#, "https://freebitco.in/signup/?op=s")
